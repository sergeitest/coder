# %% [markdown]
# <img src="http://files.oproject.org/img/HeaderOpenData.png">
# # CMS Open Data Example #6: Fitting the J/$\psi$ fit
#
# ## Import required modules

# %%
from ROOT import TFile, TCanvas, TH1F, TLorentzVector
# %jsroot on

# %% [markdown]
# ## Read in Data from Input File

# %%
file = TFile("../data/Dimuons.root","READ");

# %% [markdown]
# ## Declare Histograms

# %%
Jpsi = TH1F("Jpsi","#mu#mu mass;#mu#mu mass [GeV];Events", 1000, 2, 3.5)

# %% [markdown]
# # Compute Invariant Mass of J/$\psi$

# %%
for dimu in file.Dimuons:

    if dimu.Muon1_Global and dimu.Muon2_Global:     
    
        muon1 = TLorentzVector(dimu.Muon1_Px, dimu.Muon1_Py, dimu.Muon1_Pz, dimu.Muon1_Energy)
    
        muon2 = TLorentzVector(dimu.Muon2_Px, dimu.Muon2_Py, dimu.Muon2_Pz, dimu.Muon2_Energy)
    
        InvariantMass = (muon1 + muon2).M() 
        
        if InvariantMass > 2.0 and InvariantMass < 4.0:

            Jpsi.Fill(InvariantMass)

# %% [markdown]
# ## Fitting the J/$\psi$ Peak

# %%
from ROOT import TF1, kGreen, kRed

Canvas = TCanvas()

# %% [markdown]
# Possible fitting options: <BR>
# "gaus" gaussian <BR>
# "pol1" 1st order polynomial <BR>

# %%
Gaussian = TF1("Gaussian","gaus", 3.03, 3.16)
Background  = TF1("Background","pol1", 2, 3.5)

Gaussian.SetLineColor(kRed)
Background.SetLineColor(kGreen)

Jpsi.Fit(Gaussian,"R")
Jpsi.Fit(Background,"R+")

Canvas.Draw()
# Out:
#  FCN=238.61 FROM MIGRAD    STATUS=CONVERGED      71 CALLS          72 TOTAL
#                      EDM=7.76303e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     5.82050e+02   4.65629e+00   2.59691e-02  -1.64617e-05
#    2  Mean         3.09292e+00   2.01159e-04   1.51576e-06   9.89004e-02
#    3  Sigma        3.05871e-02   2.03936e-04   1.30856e-05   2.50483e-02
#
# ****************************************
# Minimizer is Linear
# Chi2                      =      28549.5
# NDf                       =          998
# p0                        =      65.9587   +/-   0.923571
# p1                        =     -15.3932   +/-   0.313802
# <div id="root_plot_3"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":1.000000e-01,"fRightMargin":1.000000e-01,"fBottomMargin":1.000000e-01,"fTopMargin":1.000000e-01,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":9.900000e-01,"fYstat":9.900000e-01,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":1.812500e+00,"fY1":-8.439376e+01,"fX2":3.687500e+00,"fY2":7.595438e+02,"fXtoAbsPixelk":-6.727999e+02,"fXtoPixelk":-6.727999e+02,"fXtoPixel":3.712000e+02,"fYtoAbsPixelk":4.248000e+02,"fYtoPixelk":4.248000e+02,"fYtoPixel":-5.592831e-01,"fUtoAbsPixelk":5.000000e-05,"fUtoPixelk":5.000000e-05,"fUtoPixel":696,"fVtoAbsPixelk":4.720000e+02,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":1.812500e+00,"fPixeltoXk":1.812500e+00,"fPixeltoX":2.693966e-03,"fAbsPixeltoYk":7.595438e+02,"fPixeltoYk":-8.439376e+01,"fPixeltoY":-1.788003e+00,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":2,"fUymin":0,"fUxmax":3.500000e+00,"fUymax":6.751500e+02,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":2,"fY1":0,"fX2":3.500000e+00,"fY2":6.751500e+02,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50331656,"fName":"Jpsi","fTitle":"#mu#mu mass","fLineColor":602,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":600,"fMarkerStyle":8,"fMarkerSize":5.000000e-01,"fNcells":1002,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"#mu#mu mass [GeV]","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":5.000000e-03,"fLabelSize":3.500000e-02,"fTickLength":3.000000e-02,"fTitleOffset":1,"fTitleSize":3.500000e-02,"fTitleColor":1,"fTitleFont":42,"fNbins":1000,"fXmin":2,"fXmax":3.500000e+00,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"Events","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":5.000000e-03,"fLabelSize":3.500000e-02,"fTickLength":3.000000e-02,"fTitleOffset":1,"fTitleSize":3.500000e-02,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":5.000000e-03,"fLabelSize":3.500000e-02,"fTickLength":3.000000e-02,"fTitleOffset":1,"fTitleSize":3.500000e-02,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":55884,"fTsumw":52177,"fTsumw2":52177,"fTsumwx":1.504990e+05,"fTsumwx2":4.407117e+05,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TF1","fUniqueID":0,"fBits":50332680,"fName":"Gaussian","fTitle":"gaus","fLineColor":632,"fLineStyle":1,"fLineWidth":3,"fFillColor":19,"fFillStyle":0,"fMarkerColor":600,"fMarkerStyle":8,"fMarkerSize":5.000000e-01,"fXmin":3.030000e+00,"fXmax":3.160000e+00,"fNpar":3,"fNdim":1,"fNpx":100,"fType":0,"fNpfits":86, ...

# %%
from ROOT import TFile, TCanvas, TH1F, TLorentzVector
# %jsroot on

file = TFile("../data/Dimuons.root","READ");

z_boson = TH1F("zboson","#mu#mu mass;#mu#mu mass [GeV];Events", 1000, 70, 120)

for dimu in file.Dimuons:

    if dimu.Muon1_Global and dimu.Muon2_Global:     
    
        muon1 = TLorentzVector(dimu.Muon1_Px, dimu.Muon1_Py, dimu.Muon1_Pz, dimu.Muon1_Energy)
    
        muon2 = TLorentzVector(dimu.Muon2_Px, dimu.Muon2_Py, dimu.Muon2_Pz, dimu.Muon2_Energy)
    
        InvariantMass = (muon1 + muon2).M() 
        
        if InvariantMass > 70.0 and InvariantMass < 120.0:

            z_boson.Fill(InvariantMass)
            
from ROOT import TF1, kGreen, kRed

Canvas = TCanvas()

Gaussian = TF1("Gaussian","gaus", 87, 95)
Background  = TF1("Background","pol1", 70, 120)

Gaussian.SetLineColor(kRed)
Background.SetLineColor(kGreen)

z_boson.Fit(Gaussian,"R")
z_boson.Fit(Background,"R+")

Canvas.Draw()
# Out:
#  FCN=268.513 FROM MIGRAD    STATUS=CONVERGED      72 CALLS          73 TOTAL
#                      EDM=8.59885e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.36718e+02   2.11587e+00   1.23773e-02   1.59380e-04
#    2  Mean         9.08217e+01   1.61174e-02   1.28180e-04   1.90289e-02
#    3  Sigma        2.10257e+00   1.75197e-02   1.75692e-05   1.38617e-01
#
# ****************************************
# Minimizer is Linear
# Chi2                      =      24551.1
# NDf                       =          943
# p0                        =       41.589   +/-   0.584721
# p1                        =    -0.347113   +/-   0.00546932
# <div id="root_plot_2"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":1.000000e-01,"fRightMargin":1.000000e-01,"fBottomMargin":1.000000e-01,"fTopMargin":1.000000e-01,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":9.900000e-01,"fYstat":9.900000e-01,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":6.375000e+01,"fY1":-3.596250e+01,"fX2":1.262500e+02,"fY2":3.236625e+02,"fXtoAbsPixelk":-7.099199e+02,"fXtoPixelk":-7.099199e+02,"fXtoPixel":1.113600e+01,"fYtoAbsPixelk":4.248000e+02,"fYtoPixelk":4.248000e+02,"fYtoPixel":-1.312478e+00,"fUtoAbsPixelk":5.000000e-05,"fUtoPixelk":5.000000e-05,"fUtoPixel":696,"fVtoAbsPixelk":4.720000e+02,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":6.375000e+01,"fPixeltoXk":6.375000e+01,"fPixeltoX":8.979885e-02,"fAbsPixeltoYk":3.236625e+02,"fPixeltoYk":-3.596250e+01,"fPixeltoY":-7.619174e-01,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":70,"fUymin":0,"fUxmax":120,"fUymax":2.877000e+02,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":70,"fY1":0,"fX2":120,"fY2":2.877000e+02,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50331656,"fName":"zboson","fTitle":"#mu#mu mass","fLineColor":602,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":600,"fMarkerStyle":8,"fMarkerSize":5.000000e-01,"fNcells":1002,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"#mu#mu mass [GeV]","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":5.000000e-03,"fLabelSize":3.500000e-02,"fTickLength":3.000000e-02,"fTitleOffset":1,"fTitleSize":3.500000e-02,"fTitleColor":1,"fTitleFont":42,"fNbins":1000,"fXmin":70,"fXmax":120,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"Events","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":5.000000e-03,"fLabelSize":3.500000e-02,"fTickLength":3.000000e-02,"fTitleOffset":1,"fTitleSize":3.500000e-02,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":5.000000e-03,"fLabelSize":3.500000e-02,"fTickLength":3.000000e-02,"fTitleOffset":1,"fTitleSize":3.500000e-02,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":33071,"fTsumw":33071,"fTsumw2":33071,"fTsumwx":2.973661e+06,"fTsumwx2":2.685584e+08,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TF1","fUniqueID":0,"fBits":50332680,"fName":"Gaussian","fTitle":"gaus","fLineColor":632,"fLineStyle":1,"fLineWidth":3,"fFillColor":19,"fFillStyle":0,"fMarkerColor":600,"fMarkerStyle":8,"fMarkerSize":5.000000e-01,"fXmin":87,"fXmax":95,"fNpar":3,"fNdim":1,"fNpx":100,"fType":0,"fNpfits":160,"fNDF":157,"fChisquare":2.685131e+02,"fMi ...

# %%
from ROOT import TFile, TCanvas, TH1F, TLorentzVector
# %jsroot on

file = TFile("../data/Dimuons.root","READ");

upsilon = TH1F("upsilon","#mu#mu mass;#mu#mu mass [GeV];Events", 1000, 8.0, 12.0)

for dimu in file.Dimuons:

    if dimu.Muon1_Global and dimu.Muon2_Global:     
    
        muon1 = TLorentzVector(dimu.Muon1_Px, dimu.Muon1_Py, dimu.Muon1_Pz, dimu.Muon1_Energy)
    
        muon2 = TLorentzVector(dimu.Muon2_Px, dimu.Muon2_Py, dimu.Muon2_Pz, dimu.Muon2_Energy)
    
        InvariantMass = (muon1 + muon2).M() 
        
        if InvariantMass > 8.0 and InvariantMass < 12.0:

            upsilon.Fill(InvariantMass)
# Out:
# Welcome to JupyROOT 6.07/07

# %%
from ROOT import TF1, kGreen, kRed

Canvas = TCanvas()

Gaussian = TF1("Gaussian","gaus", 9.3, 9.6)
Gaussian2 = TF1("Gaussian2","gaus", 9.84, 10.16)
Gaussian3 = TF1("Gaussian3","gaus", 10.2, 10.5)
Background  = TF1("Background","pol1", 8, 12)

Gaussian.SetLineColor(kRed)
Gaussian2.SetLineColor(kRed)
Gaussian3.SetLineColor(kRed)
Background.SetLineColor(kGreen)

upsilon.Fit(Gaussian,"R")
upsilon.Fit(Gaussian2,"R2+")
upsilon.Fit(Gaussian3,"R3+")
upsilon.Fit(Background,"R+")

Canvas.Draw()
# Out:
#  FCN=79.829 FROM MIGRAD    STATUS=CONVERGED      89 CALLS          90 TOTAL
#                      EDM=4.19646e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.12407e+02   2.73248e+00   8.48712e-03   1.08776e-05
#    2  Mean         9.45177e+00   1.42689e-03   6.25756e-06   2.67027e-03
#    3  Sigma        1.09200e-01   2.04239e-03   2.37270e-05   5.27763e-03
#  FCN=75.2579 FROM MIGRAD    STATUS=CONVERGED      84 CALLS          85 TOTAL
#                      EDM=7.31957e-10    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.6 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.21647e+02   1.93729e+00   1.66805e-03  -3.12560e-05
#    2  Mean         1.00152e+01   3.65123e-03  -2.47985e-06   5.59594e-03
#    3  Sigma        1.65543e-01   7.09809e-03  -1.04327e-05  -1.09809e-03
#  FCN=67.0953 FROM MIGRAD    STATUS=CONVERGED     112 CALLS         113 TOTAL
#                      EDM=1.09651e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.03373e+02   1.76854e+00   4.89702e-03  -8.22534e-05
#    2  Mean         1.03350e+01   8.08859e-03   3.00292e-05  -4.48081e-03
#    3  Sigma        2.32207e-01   2.24293e-02   1.56126e-04  -3.78166e-03
#
# ****************************************
# Minimizer is Linear
# Chi2                      =      9741.05
# NDf                       =          998
# p0                        =     -140.444   +/-   1.79423
# p1                        =      20.6121   +/-   0.188834
# <div id="root_plot_1"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":1.000000e-01,"fRightMargin":1.000000e-01,"fBottomMargin":1.000000e-01,"fTopMargin":1.000000e-01,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":9.900000e-01,"fYstat":9.900000e-01,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":7.500000e+00,"fY1":-3.058125e+01,"fX2":1.250000e+01,"fY2":2.752313e+02,"fXtoAbsPixelk":-1.044000e+03,"fXtoPixelk":-1.044000e+03,"fXtoPixel":1.392000e+02,"fYtoAbsPixelk":4.248000e+02,"fYtoPixelk":4.248000e+02,"fYtoPixel":-1.543429e+00,"fUtoAbsPixelk":5.000000e-05,"fUtoPixelk":5.000000e-05,"fUtoPixel":696,"fVtoAbsPixelk":4.720000e+02,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":7.500000e+00,"fPixeltoXk":7.500000e+00,"fPixeltoX":7.183908e-03,"fAbsPixeltoYk":2.752313e+02,"fPixeltoYk":-3.058125e+01,"fPixeltoY":-6.479078e-01,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":8,"fUymin":0,"fUxmax":12,"fUymax":2.446500e+02,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":8,"fY1":0,"fX2":12,"fY2":2.446500e+02,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50331656,"fName":"upsilon","fTitle":"#mu#mu mass","fLineColor":602,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":600,"fMarkerStyle":8,"fMarkerSize":5.000000e-01,"fNcells":1002,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"#mu#mu mass [GeV]","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":5.000000e-03,"fLabelSize":3.500000e-02,"fTickLength":3.000000e-02,"fTitleOffset":1,"fTitleSize":3.500000e-02,"fTitleColor":1,"fTitleFont":42,"fNbins":1000,"fXmin":8,"fXmax":12,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"Events","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":5.000000e-03,"fLabelSize":3.500000e-02,"fTickLength":3.000000e-02,"fTitleOffset":1,"fTitleSize":3.500000e-02,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":5.000000e-03,"fLabelSize":3.500000e-02,"fTickLength":3.000000e-02,"fTitleOffset":1,"fTitleSize":3.500000e-02,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":75418,"fTsumw":75418,"fTsumw2":75418,"fTsumwx":7.732381e+05,"fTsumwx2":8.000814e+06,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TF1","fUniqueID":0,"fBits":50332680,"fName":"Gaussian","fTitle":"gaus","fLineColor":632,"fLineStyle":1,"fLineWidth":3,"fFillColor":19,"fFillStyle":0,"fMarkerColor":600,"fMarkerStyle":8,"fMarkerSize":5.000000e-01,"fXmin":9.300000e+00,"fXmax":9.600000e+00,"fNpar":3,"fNdim":1,"fNpx":100,"fType":0,"fNpfits":75,"fNDF":72,"fChisquare":7.98 ...
